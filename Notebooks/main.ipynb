# %%
# Importing Dependencies 
import pandas as pd

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# InteractiveShell.ast_node_interactivity = "last_expr"

# %%
# Read data from an excel file to a pandas dataframe 
election_data_unclean = pd.read_excel('../Data/ResultatElection2019.xlsx')

# %% [markdown]
# #### Let's familiarize ourselves with the data <br> [source: CENI](http://www.ceni.mr/node/91)

# %%
# Print first five rows
election_data_unclean.head()
# Out:
#    codeWilaya libWilaya_ar libMoughataaAr libCommune_ar libelleCenter_ar  \
# 0          10   كيدي ماغا            غابو        بادجيم       مدرسة كليل
# 1          10   كيدي ماغا            غابو        بادجيم       مدرسة كليل
# 2          10   كيدي ماغا            غابو        بادجيم       مدرسة كليل
# 3          10   كيدي ماغا            غابو        بادجيم       مدرسة كليل
# 4          10   كيدي ماغا            غابو        بادجيم       مدرسة كليل
#
#     libWilaya libMoughataaFr libCommune  libelleCenter  N Centre  N Bureau  \
# 0  Guidimagha         Ghabou    Baydjam  Ecole Keleyle         7         1
# 1  Guidimagha         Ghabou    Baydjam  Ecole Keleyle         7         1
# 2  Guidimagha         Ghabou    Baydjam  Ecole Keleyle         7         1
# 3  Guidimagha         Ghabou    Baydjam  Ecole Keleyle         7         1
# 4  Guidimagha         Ghabou    Baydjam  Ecole Keleyle         7         1
#
#    nbInscrits  nbVotant  nbVoteNull  nbVoteNeutre  nbSuffrage  nbVoix  \
# 0         164       120           5             0         115      96
# 1         164       120           5             0         115      13
# 2         164       120           5             0         115       6
# 3         164       120           5             0         115       0
# 4         164       120           5             0         115       0
#
#                                             Candidat  \
# 0  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 1         Sidi Mohamed Boubacar BOUSSALEF (Boubacar)
# 2                        Biram Dah Dah ABEID (Biram)
# 3                   Mohamed Sidi MAOULOUD (Maouloud)
# 4          Mohamed Lemine El Mourteji El WAVI (Wavi)
#
#                             CandidatAr
# 0  محمد الشيخ محمد أحمد الشيخ الغزواني
# 1               سيدي محمد بوبكر بوسالف
# 2               برام الداه الداه اعبيد
# 3                      محمد سيدي مولود
# 4           محمد الامين المرتجي الوافي

# %%
print(f'the number of unique voting offices: {int(23166/6)}')
# Out:
# the number of unique voting offices: 3861

# %%
# print information about the dataframe, number of columns, their names, number of entries, dtypes and memory usage
election_data_unclean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23166 entries, 0 to 23165
# Data columns (total 19 columns):
# codeWilaya          23166 non-null int64
# libWilaya_ar        23166 non-null object
# libMoughataaAr      23166 non-null object
# libCommune_ar       23166 non-null object
# libelleCenter_ar    23166 non-null object
# libWilaya           23166 non-null object
# libMoughataaFr      23166 non-null object
# libCommune          23166 non-null object
# libelleCenter       23166 non-null object
# N Centre            23166 non-null int64
# N Bureau            23166 non-null int64
# nbInscrits          23166 non-null int64
# nbVotant            23166 non-null int64
# nbVoteNull          23166 non-null int64
# nbVoteNeutre        23166 non-null int64
# nbSuffrage          23166 non-null int64
# nbVoix              23166 non-null int64
# Candidat            23166 non-null object
# CandidatAr          23166 non-null object
# dtypes: int64(9), object(10)
# memory usage: 3.4+ MB

# %%
# Check for null values in any of the columns 
election_data_unclean.isnull().any()
# Out:
# codeWilaya          False
# libWilaya_ar        False
# libMoughataaAr      False
# libCommune_ar       False
# libelleCenter_ar    False
# libWilaya           False
# libMoughataaFr      False
# libCommune          False
# libelleCenter       False
# N Centre            False
# N Bureau            False
# nbInscrits          False
# nbVotant            False
# nbVoteNull          False
# nbVoteNeutre        False
# nbSuffrage          False
# nbVoix              False
# Candidat            False
# CandidatAr          False
# dtype: bool

# %%
# print candidate names
candidates_list = election_data_unclean["Candidat"].unique()
candidates_list
# Out:
# array(['Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghazouani)',
#        'Sidi Mohamed Boubacar BOUSSALEF (Boubacar)',
#        'Biram Dah Dah ABEID (Biram)', 'Mohamed Sidi MAOULOUD (Maouloud)',
#        'Mohamed Lemine El Mourteji El WAVI (Wavi)',
#        'KANE Hamidou Baba (Kane)'], dtype=object)

# %%
# get unique states + overseas
states_list = election_data_unclean['libWilaya'].unique()
states_list
# Out:
# array(['Guidimagha', 'Tagant', 'Brakna', 'Hodh El Gharbi',
#        'Dakhlet Nouadhibou', 'Tiris Zemmour', 'Trarza', 'Hodh Chargui',
#        'Assaba', 'Gorgol', 'Nouakchott Ouest', 'Nouakchott Sud',
#        'Inchiri', 'Adrar', 'Nouakchott Nord', 'Etranger'], dtype=object)

# %%
# print column names
election_data_unclean.columns.values
# Out:
# array(['codeWilaya', 'libWilaya_ar', 'libMoughataaAr', 'libCommune_ar',
#        'libelleCenter_ar', 'libWilaya', 'libMoughataaFr', 'libCommune',
#        'libelleCenter', 'N Centre', 'N Bureau', 'nbInscrits', 'nbVotant',
#        'nbVoteNull', 'nbVoteNeutre', 'nbSuffrage', 'nbVoix', 'Candidat',
#        'CandidatAr'], dtype=object)

# %% [markdown]
# #### Data manipulation

# %%
# drop unwanted columns
election_data_unclean = election_data_unclean.drop(['libWilaya_ar',
                                                    'libMoughataaAr',
                                                    'libCommune_ar',
                                                    'libelleCenter_ar',
                                                    'CandidatAr'], axis = 1)

# %%
# list with english column names
english_headers_list = [
                        'state_code',
                        'state',
                        'county',
                        'town',
                        'center',
                        'center_id',
                        'office_id',
                        'registered',
                        'voted',
                        'void',
                        'neutral',
                        'suffrage',
                        'candidate_votes',
                        'candidate'
                                        ]

# %%
# rename dataframe's headers
election_data_unclean.columns = english_headers_list

# %%
election_data_unclean.tail()
# Out:
#        state_code   state county       town     center  center_id  office_id  \
# 23161           4  Gorgol  Kaédi  Tokomadji  Tokomadji          7          1
# 23162           4  Gorgol  Kaédi  Tokomadji  Tokomadji          7          1
# 23163           4  Gorgol  Kaédi  Tokomadji  Tokomadji          7          1
# 23164           4  Gorgol  Kaédi  Tokomadji  Tokomadji          7          1
# 23165           4  Gorgol  Kaédi  Tokomadji  Tokomadji          7          1
#
#        registered  voted  void  neutral  suffrage  candidate_votes  \
# 23161         321    231     2        4       225               17
# 23162         321    231     2        4       225               69
# 23163         321    231     2        4       225                3
# 23164         321    231     2        4       225                0
# 23165         321    231     2        4       225               77
#
#                                         candidate
# 23161  Sidi Mohamed Boubacar BOUSSALEF (Boubacar)
# 23162                 Biram Dah Dah ABEID (Biram)
# 23163            Mohamed Sidi MAOULOUD (Maouloud)
# 23164   Mohamed Lemine El Mourteji El WAVI (Wavi)
# 23165                    KANE Hamidou Baba (Kane)

# %%
# dtypes dict 
convert_dtypes = {'registered':int,
                  'voted': int,
                  'void': int,
                  'neutral': int,
                  'suffrage': int,
                  'candidate_votes': int}

# change dtypes 
election_data_unclean = election_data_unclean.astype(convert_dtypes)
election_data_unclean.dtypes

# 
election_data = election_data_unclean
# Out:
# state_code          int64
# state              object
# county             object
# town               object
# center             object
# center_id           int64
# office_id           int64
# registered          int64
# voted               int64
# void                int64
# neutral             int64
# suffrage            int64
# candidate_votes     int64
# candidate          object
# dtype: object

# %%
election_data_unclean[election_data_unclean['state']=='Etranger'].head()
# Out:
#       state_code     state county                 town       center  \
# 7542           0  Etranger   Asie  Emirats Arabes Unis  Interieur 1
# 7543           0  Etranger   Asie  Emirats Arabes Unis  Interieur 1
# 7544           0  Etranger   Asie  Emirats Arabes Unis  Interieur 1
# 7545           0  Etranger   Asie  Emirats Arabes Unis  Interieur 1
# 7546           0  Etranger   Asie  Emirats Arabes Unis  Interieur 1
#
#       center_id  office_id  registered  voted  void  neutral  suffrage  \
# 7542          2          1         465    255     3       10       242
# 7543          2          1         465    255     3       10       242
# 7544          2          1         465    255     3       10       242
# 7545          2          1         465    255     3       10       242
# 7546          2          1         465    255     3       10       242
#
#       candidate_votes                                          candidate
# 7542              165  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 7543               47         Sidi Mohamed Boubacar BOUSSALEF (Boubacar)
# 7544                7                        Biram Dah Dah ABEID (Biram)
# 7545               22                   Mohamed Sidi MAOULOUD (Maouloud)
# 7546                0          Mohamed Lemine El Mourteji El WAVI (Wavi)

# %%
# # save as csv
# election_data.to_csv(path_or_buf='../Data/election_data.csv')

# %%
mauri_states = ['Guidimagha', 'Tagant', 'Brakna', 'Hodh El Gharbi',
       'Dakhlet Nouadhibou', 'Tiris Zemmour', 'Trarza', 'Hodh Chargui',
       'Assaba', 'Gorgol', 'Nouakchott Ouest', 'Nouakchott Sud',
       'Inchiri', 'Adrar', 'Nouakchott Nord',]

# %%
# df with on mauritanian states, not including etranger 
mauri_states_df = election_data[election_data.state.isin(mauri_states)]
mauri_states_df.shape
# Out:
# (22896, 14)

# %%
# gaz = election_data[(election_data.candidate == candidates_list[0]) & (election_data.voted > 200)]
gaz = election_data[(election_data.candidate == candidates_list[0])]

# %%
gaz.candidate_votes.sum() / gaz.suffrage.sum()
# Out:
# 0.5200761855570262

# %%
guid_gaz_df = election_data[(election_data.state == mauri_states[0]) & (election_data.candidate == candidates_list[0])]

# %%
# Out:
#        state_code       state      county        town  \
# 0              10  Guidimagha      Ghabou     Baydjam
# 384            10  Guidimagha      Ghabou     Baydjam
# 408            10  Guidimagha      Ghabou      Ghabou
# 414            10  Guidimagha      Ghabou      Ghabou
# 522            10  Guidimagha      Ghabou     Baydjam
# 660            10  Guidimagha      Ghabou      Ghabou
# 792            10  Guidimagha      Ghabou       Souvi
# 810            10  Guidimagha      Ghabou      Ghabou
# 996            10  Guidimagha      Ghabou      Ghabou
# 1074           10  Guidimagha      Ghabou      Ghabou
# 1188           10  Guidimagha      Ghabou     Baydjam
# 1194           10  Guidimagha    Sélibaby    Sélibaby
# 1200           10  Guidimagha    Sélibaby    Sélibaby
# 1206           10  Guidimagha    Sélibaby    Sélibaby
# 1242           10  Guidimagha  Ould Yengé  Ould Yengé
# 1248           10  Guidimagha      Ghabou      Ghabou
# 1722           10  Guidimagha    Sélibaby    Sélibaby
# 1842           10  Guidimagha    Sélibaby    Sélibaby
# 1992           10  Guidimagha    Sélibaby    Sélibaby
# 2208           10  Guidimagha    Sélibaby    Sélibaby
# 2418           10  Guidimagha    Sélibaby    Sélibaby
# 2616           10  Guidimagha    Sélibaby    Sélibaby
# 3270           10  Guidimagha  Ould Yengé     Tektake
# 3330           10  Guidimagha  Ould Yengé     Tektake
# 3342           10  Guidimagha  Ould Yengé   Leaweinat
# 3702           10  Guidimagha  Ould Yengé   Leaweinat
# 4686           10  Guidimagha  Ould Yengé  Ould Yengé
# 5280           10  Guidimagha  Ould Yengé  Ould Yengé
# 5532           10  Guidimagha  Ould Yengé    Leboully
# 6486           10  Guidimagha  Ould Yengé  Ould Yengé
# ...           ...         ...         ...         ...
# 21978          10  Guidimagha  Ould Yengé      Lehraj
# 21990          10  Guidimagha  Ould Yengé      Lehraj
# 22002          10  Guidimagha  Ould Yengé      Lehraj
# 22008          10  Guidimagha  Ould Yengé      Lehraj
# 22014          10  Guidimagha  Ould Yengé      Lehraj
# 22020          10  Guidimagha  Ould Yengé      Lehraj
# 22032          10  Guidimagha  Ould Yengé      Lehraj
# 22038          10  Guidimagha  Ould Yengé      Lehraj
# 22044          10  Guidimagha  Ould Yengé      Lehraj
# 22050          10  Guidimagha  Ould Yengé      Dafort
# 22062          10  Guidimagha  Ould Yengé      Dafort
# 22080          10  Guidimagha  Ould Yengé      Dafort
# 22086          10  Guidimagha  Ould Yengé      Dafort
# 22140          10  Guidimagha  Ould Yengé      Dafort
# 22146          10  Guidimagha  Ould Yengé      Dafort
# 22170          10  Guidimagha  Ould Yengé      Dafort
# 22236          10  Guidimagha  Ould Yengé      Dafort
# 22248          10  Guidimagha  Ould Yengé      Dafort
# 22260          10  Guidimagha  Ould Yengé      Dafort
# 22272          10  Guidimagha  Ould Yengé      Bouanz
# 22740          10  Guidimagha      Ghabou      Ghabou
# 22746          10  Guidimagha      Ghabou      Ghabou
# 22752          10  Guidimagha      Ghabou      Ghabou
# 22758          10  Guidimagha      Ghabou      Ghabou
# 22764          10  Guidimagha      Ghabou      Ghabou
# 22770          10  Guidimagha      Ghabou      Ghabou
# 22776          10  Guidimagha      Ghabou      Ghabou
# 22782          10  Guidimagha      Ghabou      Ghabou
# 22788          10  Guidimagha      Ghabou      Ghabou
# 22836          10  Guidimagha      Ghabou     Baydjam
#
#                               center  center_id  office_id  registered  voted  \
# 0                      Ecole Keleyle          7          1         164    120
# 384                    Ecole Chiyé 2          3          1         366    234
# 408                    Centre Mballe          1          1         221    143
# 414                   Collège Ghabou          3          1         491    326
# 522                    Ecole Baédiam          2          1         514    326
# 660                        Sabouciré         15          2         377    286
# 792    Ecole Amagué Ehle El Moukhtar          2          1         522    365
# 810          Dispensaire Koumba Ndaw          6          2         386    215
# 996                   Commune Ghabou          4          1         493    298
# 1074       Dispensaire Dioguentourou          5          1         335    236
# 1188                  Ecole Sed Elem          9          1         196    154
# 1194                        Ecole 11          3          1         469    347
# 1200          Ecole M'Beighiré bilal         10          1         435    340
# 1206                         Commune          1          2         562    335
# 1242                       Libheiré           6          1         308    214
# 1248                  Commune Ghabou          4          2         493    286
# 1722                         Ecole 5          7          1         324    236
# 1842                         Ecole 5          7          2         324    230
# 1992                        Ecole 11          3          2         465    296
# 2208                         Ecole 6          8          1         358    279
# 2418                         Ecole 2          4          1         520    365
# 2616                         Ecole 2          4          2         518    341
# 3270         Ecole Teidoumeh Voulane          3          1         383    134
# 3330        Ecole Teidouma Zbeiratte          2          1         290    184
# 3342                 Ecole Leweinatt          1          1         372    206
# 3702            Ecole Mesyel Lehbech          2          1         497    188
# 4686              Ecole 2 Ould Yengé          2          1         543    308
# 5280                         Commune          1          2         515    360
# 5532                         Commune          1          2         451    316
# 6486                         Commune          1          1         516    313
# ...                              ...        ...        ...         ...    ...
# 21978                   Ecole Lehraj          5          2         331    201
# 21990             Ecole Lemghaichene          6          1         146     91
# 22002         Centre de Santé Lehraj          2          1         394    204
# 22008                   Ecole Lehraj          5          1         332    148
# 22014                  Ecole Boungue          4          1         140    106
# 22020           Ecole Oudhen Levrass          7          1         300    203
# 22032                    Hassi Bakar          9          1         164    108
# 22038                Aghweine Leibid          1          1         118     65
# 22044                   Ecole Zweire          8          1         256    163
# 22050                    Ecole Dafor          5          1         418    301
# 22062                  Commune Dafor          1          2         355    261
# 22080             Dispensaire Dafour          2          1         334    222
# 22086             Ecole Mbeidi'e Sag          7          1         493    331
# 22140      Dispensaire Mbeidi'e Sagh          3          2         377    259
# 22146      Dispensaire Mbeidi'e Sagh          3          1         379    243
# 22170                  Commune Dafor          1          1         356    254
# 22236                Ecole Bouguerba          4          1         455    342
# 22248             Ecole Ehel Jeilany          6          1         570    415
# 22260                    Ecole Dafor          5          2         417    306
# 22272                  Ecole Bouanze          4          2         580    320
# 22740                  Chlekha Ecole          2          1         230    168
# 22746              Ecole Boukediamby          8          1         243    208
# 22752                 Ecole Boulhaya          9          1         341    273
# 22758            Ecole Dioguentourou         10          1         373    276
# 22764            Ecole Dioguentourou         10          2         373    259
# 22770                    Ecole Kimou         12          1         467    368
# 22776                  Ecole Mouslim         13          1         267    173
# 22782                   Ecole Sollou         14          1         313    221
# 22788                          Baata         16          1         147    122
# 22836                Commune Baédiam          1          1         291    180
#
#        void  neutral  suffrage  candidate_votes  \
# 0         5        0       115               96
# 384      12        0       222               82
# 408      11        4       128               78
# 414       9        4       313              136
# 522       3        5       318              211
# 660       9        6       271              123
# 792       2        0       363              208
# 810      14        4       197               85
# 996      10        3       285              180
# 1074      5        2       229              100
# 1188     11        0       143               62
# 1194     14        1       332               88
# 1200     19        0       321               44
# 1206      9        0       326               77
# 1242      4        0       210              118
# 1248     11        1       274              157
# 1722     26        0       210               32
# 1842     20        0       210               28
# 1992     20        2       274               62
# 2208     23        4       252               50
# 2418      7        2       356               57
# 2616      6        3       332               38
# 3270      1        0       133               79
# 3330      9        0       175               66
# 3342      9        0       197              157
# 3702     17        3       168               83
# 4686     11        1       296               98
# 5280      9       17       334               91
# 5532      4        0       312              173
# 6486      8        3       302               89
# ...     ...      ...       ...              ...
# 21978    18        0       183              109
# 21990     0        1        90               35
# 22002     2        4       198               53
# 22008     5        2       141               77
# 22014     0        0       106               76
# 22020     0        1       202              135
# 22032     1        0       107               69
# 22038     6        0        59               23
# 22044     3        2       158               40
# 22050     4        3       294              241
# 22062     4        4       253              155
# 22080     4        0       218               94
# 22086    13        1       317              171
# 22140     6        0       253              133
# 22146     5        3       235              110
# 22170    17       14       223              151
# 22236     6        7       329              180
# 22248     7        2       406               71
# 22260    26        3       277              229
# 22272     7        1       312              177
# 22740     3        3       162              100
# 22746    19        0       189               60
# 22752    18        0       255              155
# 22758    14        0       262               74
# 22764    17        0       242               75
# 22770    11        1       356              127
# 22776    41        0       132              115
# 22782     4       13       204               80
# 22788     9        1       112               63
# 22836     5        0       175               89
#
#                                                candidate
# 0      Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 384    Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 408    Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 414    Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 522    Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 660    Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 792    Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 810    Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 996    Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 1074   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 1188   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 1194   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 1200   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 1206   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 1242   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 1248   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 1722   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 1842   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 1992   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 2208   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 2418   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 2616   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 3270   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 3330   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 3342   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 3702   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 4686   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 5280   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 5532   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 6486   Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# ...                                                  ...
# 21978  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 21990  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22002  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22008  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22014  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22020  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22032  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22038  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22044  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22050  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22062  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22080  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22086  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22140  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22146  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22170  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22236  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22248  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22260  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22272  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22740  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22746  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22752  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22758  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22764  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22770  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22776  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22782  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22788  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
# 22836  Mohamed Cheïkh Mohamed Ahmed ElGHAZOUANI (Ghaz...
#
# [191 rows x 14 columns]
