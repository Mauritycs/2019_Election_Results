# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# InteractiveShell.ast_node_interactivity = "last_expr"

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd
import plotly
import numpy as np

# %%
plotly.tools.set_credentials_file(username='ahmedamdg', api_key='ogfSzyLWtDPni5gfWAPn')

# %%
offices_summary = pd.read_csv('../Data/detailed_offices.csv')

# %%
# multiply columns by 100
offices_summary[['gaz_perct', 'biram_perct', 'mewloud_perct', 'kane_perct', 'wavi_perct', 'boubacar_perct']] *= 100

# %%
# round candidates percentages
offices_summary = offices_summary.round({'gaz_perct': 2,
                                         'biram_perct': 2,
                                         'mewloud_perct': 2,
                                         'kane_perct': 2,
                                         'wavi_perct': 2, 
                                         'boubacar_perct': 2})

# %%
offices_summary.state_name.unique()
# Out:
# array(['Guidimagha', 'Tagant', 'Brakna', 'Hodh El Gharbi',
#        'Dakhlet Nouadhibou', 'Tiris Zemmour', 'Trarza', 'Hodh Chargui',
#        'Assaba', 'Gorgol', 'Nouakchott Ouest', 'Nouakchott Sud',
#        'Inchiri', 'Adrar', 'Nouakchott Nord', 'Etranger'], dtype=object)

# %%
# state dataframes 
trarza_df = offices_summary[offices_summary['state_name'] == 'Trarza']
tagant_df = offices_summary[offices_summary['state_name'] == 'Tagant']
guidimagha_df = offices_summary[offices_summary['state_name'] == 'Guidimagha']
ndb_df = offices_summary[offices_summary['state_name'] == 'Dakhlet Nouadhibou']
gharbi_df = offices_summary[offices_summary['state_name'] == 'Hodh El Gharbi']
chargui_df = offices_summary[offices_summary['state_name'] == 'Hodh Chargui']
tiris_df = offices_summary[offices_summary['state_name'] == 'Tiris Zemmour']
assaba_df = offices_summary[offices_summary['state_name'] == 'Assaba']
nktt_ouest_df = offices_summary[offices_summary['state_name'] == 'Nouakchott Ouest']
nktt_sud_df = offices_summary[offices_summary['state_name'] == 'Nouakchott Sud']
nktt_nord_df = offices_summary[offices_summary['state_name'] == 'Nouakchott Nord']
inchiri_df = offices_summary[offices_summary['state_name'] == 'Inchiri']
adrar_df = offices_summary[offices_summary['state_name'] == 'Adrar']
brakna_df = offices_summary[offices_summary['state_name'] == 'Brakna']
gorgol_df = offices_summary[offices_summary['state_name'] == 'Gorgol']

# %%
x_data = ['Carmelo Anthony', 'Dwyane Wade',
          'Deron Williams', 'Brook Lopez',
          'Damian Lillard', 'David West',]

y0 = np.random.randn(50)-1
y1 = np.random.randn(50)+1
y2 = np.random.randn(50)
y3 = np.random.randn(50)+2
y4 = np.random.randn(50)-2
y5 = np.random.randn(50)+3

y_data = [y0,y1,y2,y3,y4,y5]

colors = ['rgba(93, 164, 214, 0.5)', 'rgba(255, 144, 14, 0.5)', 'rgba(44, 160, 101, 0.5)', 'rgba(255, 65, 54, 0.5)', 'rgba(207, 114, 255, 0.5)', 'rgba(127, 96, 0, 0.5)']

traces = []


## Trarza
trace0 = go.Box(
            y=trarza_df.turnout.tolist(),
            name='Trarza',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )
## Tagant 
trace1 = go.Box(
            y=tagant_df.turnout.tolist(),
            name='Tagant',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )

## Guidimagha
trace2 = go.Box(
            y=guidimagha_df.turnout.tolist(),
            name='Guidimagha',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )
## NDB
trace3 = go.Box(
            y=ndb_df.turnout.tolist(),
            name='Dakhlet Nouadhibou',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )

## Hodh El Gharbi
trace4 = go.Box(
            y=gharbi_df.turnout.tolist(),
            name='Hodh El Gharbi',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )

## Hodh El Chargui
trace5 = go.Box(
            y=chargui_df.turnout.tolist(),
            name='Hodh El Chargui',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )

## Tiris Zemmour 
trace6 = go.Box(
            y=tiris_df.turnout.tolist(),
            name='Tiris Zemmour',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )

## Assaba
trace7 = go.Box(
            y=assaba_df.turnout.tolist(),
            name='Assaba',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )

## Nouakchott Ouest
trace8 = go.Box(
            y=nktt_ouest_df.turnout.tolist(),
            name='Nouakchott Ouest',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )

## Nouakchott Nord 
trace9 = go.Box(
            y=nktt_nord_df.turnout.tolist(),
            name='Nouakchott Nord',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )
## Nouakchott Sud 
trace10 = go.Box(
            y=nktt_sud_df.turnout.tolist(),
            name='Nouakchott Sud',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )

## Inchiri
trace11 = go.Box(
            y=inchiri_df.turnout.tolist(),
            name='Inchiri',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )

## Adrar
trace12 = go.Box(
            y=adrar_df.turnout.tolist(),
            name='Adrar',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )

## Brakna
trace13 = go.Box(
            y=brakna_df.turnout.tolist(),
            name='Brakna',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )

## Brakna
trace14 = go.Box(
            y=gorgol_df.turnout.tolist(),
            name='Gorgol',
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=1,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
    boxmean=True,
        )


layout = go.Layout(
    title='Box Plot Showing Voting Offices % Turnout Grouped by State (Wilaya) ',
    yaxis=dict(
        title='% Turnout',
        autorange=True,
        showgrid=True,
        zeroline=True,
        dtick=20,
        gridcolor='rgb(255, 255, 255)',
        gridwidth=1,
        zerolinecolor='rgb(255, 255, 255)',
        zerolinewidth=2,
    ),
    margin=dict(
        l=40,
        r=30,
        b=80,
        t=100,
    ),
    paper_bgcolor='rgb(243, 243, 243)',
    plot_bgcolor='rgb(243, 243, 243)',
    showlegend=False
)

data = [trace0, trace1, trace2, trace3, trace4, trace5, trace6, trace7, trace8, trace9, trace10, trace11,
        trace12, trace13, trace14]

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ahmedamdg/270.embed" height="525px" width="100%"></iframe>

# %%
df = offices_summary[offices_summary['turnout'] > 90]

# %%
offices_90 = pd.DataFrame()

offices_90['Office Name'] = df['office_name']
offices_90['County'] = df['county_name']
# offices_90['State'] = df['state_name']
offices_90['Registered'] = df['registered']
offices_90['Suffrage'] = df['suffrage']
offices_90['% Turnout'] = df['turnout']
offices_90['Ghazouani'] = df['ghazouani_votes']
offices_90['Biram'] = df['biram_votes']
offices_90['Boubacar'] = df['boubacar_votes']
offices_90['Kane'] = df['kane_votes']
offices_90['Wavi'] = df['wavi_votes']

# %%
offices_90
# Out:
#                        Office Name            County  Registered  Suffrage  \
# 6                            Tayba             Rosso          80        70
# 36                 Ecole Mekanet 1             Kiffa          62        64
# 73                 Elbeled Elemine       Magtalahjar         162       141
# 124                       Tevradit          Boumdeid         109       102
# 177              Hay Elwiam Kendra             Kiffa         404       390
# 197                        Legdeim          Boumdeid         248       237
# 404                 Collége Amdeir              Atar          95        85
# 430                     Boumdeid 2          Boumdeid         430       388
# 461                   Ecole Tembel           Maghama         252       215
# 477                      lemreyveg              Atar         103       101
# 519                    Ehl Gdawiya              Néma          90        86
# 597                          Negya              Néma          38        35
# 644                   Oum Lewategh          Mederdra          63        52
# 670                     Taghendmet              Atar          79        72
# 821                   FAS - Mhawda          Zoueratt          45        40
# 842                 FAS - Cheguatt         F'Deirick         128       148
# 890                FAS - Lemghetti         F'Deirick          71       135
# 1166                    Oum Awajil          Timbedra         242       244
# 1175              Ecole Baghaiditt         Djiguenni          62        57
# 1213                       Laeouej            Amourj         254       229
# 1219                        Teslah          Boumdeid         387       356
# 1225                Idriss lekhdar              Néma         285       275
# 1262                        Teslah          Boumdeid         386       374
# 1422                       Ecole 4            Sebkha         522       421
# 1429                        Brouda          Boumdeid         403       368
# 1482                        Dehara          Boumdeid         263       253
# 1500            Ecole Bir El Veouz             Boghé         291       253
# 1544                       El Kouz          Boumdeid          71        67
# 1577                        Nezaha            Amourj          87        78
# 1789             FAS - Ain Bintili      Bir Moghrein          69        70
# ...                            ...               ...         ...       ...
# 2695            Ecole 1 El Mebdoua            Amourj         370       330
# 2706  Ecole Ghered Ehel Issa Bewba             Kiffa         347       310
# 2733                        Chegue              Aleg         313       294
# 2861                 El Menchentah          Timbedra         205       192
# 2872                      N'yergue           Tintane          37        34
# 3039                       Boumbri       Keur Macène          69        65
# 3049                Ecole Lemseidi           Aoujeft         262       247
# 3237                     El Batine           Aoujeft         307       276
# 3260                 Hassi Lebiadh  N'beiket Lahwach         133       121
# 3322                     BEGHERDHA         Tamcheket         379       358
# 3346               Leweinatt ecole         Tamcheket         138       129
# 3371                       Melssat          Tidjikja         197       189
# 3385            Sondage Tejekanett  N'beiket Lahwach         198       185
# 3532                    Ecole Yare        Boutilimit         210       200
# 3539               Ecole Bir Leben        Boutilimit         469       412
# 3557            Ecole Ain Essalama        Boutilimit         414       381
# 3558            Ecole Ain Essalama        Boutilimit         412       387
# 3617                 Bir tejekanet        Boutilimit          92        91
# 3626             El Beled El Emine        Boutilimit         486       464
# 3627             El Beled El Emine        Boutilimit         486       485
# 3628             El Beled El Emine        Boutilimit         486       479
# 3629             El Beled El Emine        Boutilimit         486       452
# 3630             El Beled El Emine        Boutilimit         486       465
